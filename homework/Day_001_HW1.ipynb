# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

# %%
x_lin = np.linspace(0, 100, 101)

# %%
y = (x_lin + np.random.randn(101)* 5)*w + b

# %%
plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_square_error(y, yp):
    mse = MSE = sum((y - yp)**2 / len(y))
    return mse

# %%
MSE = mean_square_error(y, y_hat)
print("The Mean square error is %.3f" % (MSE))
# Out:
# The Mean square error is 232.220

# %%
'''作業2
****************************************
資料 :  Credit Card Fraud Detection

1. 你選的這組資料為何重要
A: 透過機器學習的方式，信用卡公司可以避免信用卡詐騙的交易產生，進而保障消費者的權益

2. 資料從何而來 
A: 資料來源:Worldline and the Machine Learning Group of ULB (Université Libre de Bruxelles) 
   on big data mining and fraud detection.
   2013年九月其中兩天內持有信用卡之歐洲人的交易紀錄，總共有284,807件，其中有492詐騙交易 

3. 蒐集而來的資料型態為何
A: 只有數據型態的資料，28個變數為PCA轉換後之資料，其中Time與Amount並未以PCA方式轉換

4. 這組資料想解決的問題如何評估
A: 由於資料的比例過度不平衡，以Area Under the Precision-Recall Curve (AUPRC)方法進行建模

# %%
'''作業3
****************************************
想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：

1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
目標:如何維持每天的載客目標，並增加業績
假設一:消費者以載客車輛外觀作為搭車考量
假設二:服務態度能增加消費者叫車意願

2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
統計車隊內司機每日載客量以及使用之車輛款式、載客量大小
車隊在送達乘客於目的地時給予消費者叫車名片(電話)，並針對部分司機進行服務加強的教育訓練，統計受訓後司機所獲得的叫車量是否有顯著提升
3. 蒐集而來的資料型態為何
多以數據顯示，車輛款式為名義變數

4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
司機載客量對車輛款式做迴歸分析，是否消費者以載客車輛作為搭車考量，進而討論是否有統一車輛之必要
叫車量對整體司機做迴歸分析，是否受訓後司機所獲得的叫車量是否有顯著提升，以驗證假設
